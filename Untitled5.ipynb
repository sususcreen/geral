# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\naipe\OneDrive\Desktop\data\2022.csv")
df.head(10)
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
# 5     6  Luxembourg*           7,404        7,501       7,307
# 6     7       Sweden           7,384        7,454       7,315
# 7     8       Norway           7,365        7,440       7,290
# 8     9       Israel           7,364        7,426       7,301
# 9    10  New Zealand           7,200        7,279       7,120
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# ...

# %%
df7 = pd.read_csv(r"C:\Users\naipe\OneDrive\Desktop\data\2021.csv")
df7.head(10)
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe         7.842
# 1      Denmark         Western Europe         7.620
# 2  Switzerland         Western Europe         7.571
# 3      Iceland         Western Europe         7.554
# 4  Netherlands         Western Europe         7.464
# 5       Norway         Western Europe         7.392
# 6       Sweden         Western Europe         7.363
# 7   Luxembourg         Western Europe         7.324
# 8  New Zealand  North America and ANZ         7.277
# 9      Austria         Western Europe         7.268
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
# ...

# %%
df6 = pd.read_csv(r"C:\Users\naipe\OneDrive\Desktop\data\2020.csv")
df6.head(10)
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe        7.8087
# 1      Denmark         Western Europe        7.6456
# 2  Switzerland         Western Europe        7.5599
# 3      Iceland         Western Europe        7.5045
# 4       Norway         Western Europe        7.4880
# 5  Netherlands         Western Europe        7.4489
# 6       Sweden         Western Europe        7.3535
# 7  New Zealand  North America and ANZ        7.2996
# 8      Austria         Western Europe        7.2942
# 9   Luxembourg         Western Europe        7.2375
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
# ...

# %%
d5 = pd.read_csv(r"C:\Users\naipe\OneDrive\Desktop\data\2019.csv")
df5.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# ...

# %%
df4 = pd.read_csv(r"C:\Users\naipe\OneDrive\Desktop\data\2018.csv")
df4.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# ...

# %%
df3 = pd.read_csv(r"C:\Users\naipe\OneDrive\Desktop\data\2017.csv")
df3.head(10)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %%
df2 = pd.read_csv(r"C:\Users\naipe\OneDrive\Desktop\data\2016.csv")
df2.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0      Denmark             Western Europe               1            7.526
# 1  Switzerland             Western Europe               2            7.509
# 2      Iceland             Western Europe               3            7.501
# 3       Norway             Western Europe               4            7.498
# 4      Finland             Western Europe               5            7.413
# 5       Canada              North America               6            7.404
# 6  Netherlands             Western Europe               7            7.339
# 7  New Zealand  Australia and New Zealand               8            7.334
# 8    Australia  Australia and New Zealand               9            7.313
# 9       Sweden             Western Europe              10            7.291
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# ...

# %%
df1 = pd.read_csv(r"C:\Users\naipe\OneDrive\Desktop\data\2015.csv")
df1.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
data = {'2015': df8['Country'], "2016":df7['Country name'], "2017":df6['Country name'], "2018":df5['Country or region'], "2019":df4['Country or region'] ,"2020":df3['Country'],
       "2021":df2['Country'], "2022":df['Country']}

countries = pd.DataFrame(data)

# %%
countries
# Out:
#             2015         2016         2017         2018         2019  \
# 0    Switzerland      Finland      Finland      Finland      Finland
# 1        Iceland      Denmark      Denmark       Norway       Norway
# 2        Denmark  Switzerland  Switzerland      Denmark      Denmark
# 3         Norway      Iceland      Iceland      Iceland      Iceland
# 4         Canada  Netherlands       Norway  Switzerland  Switzerland
# ..           ...          ...          ...          ...          ...
# 142        Gabon        Haiti      Lesotho   Madagascar   Madagascar
# 143        Niger       Malawi        India     Zimbabwe     Zimbabwe
# 144     Cambodia      Lesotho       Malawi  Afghanistan  Afghanistan
# 145     Tanzania     Botswana        Yemen     Botswana     Botswana
# 146   Madagascar       Rwanda     Botswana       Malawi       Malawi
#
#             2020          2021         2022
# 0         Norway       Denmark      Finland
# 1        Denmark   Switzerland      Denmark
# ...

# %%
happiest = countries.head(10)
happiest
# Out:
#           2015         2016         2017         2018         2019  \
# 0  Switzerland      Finland      Finland      Finland      Finland
# 1      Iceland      Denmark      Denmark       Norway       Norway
# 2      Denmark  Switzerland  Switzerland      Denmark      Denmark
# 3       Norway      Iceland      Iceland      Iceland      Iceland
# 4       Canada  Netherlands       Norway  Switzerland  Switzerland
# 5      Finland       Norway  Netherlands  Netherlands  Netherlands
# 6  Netherlands       Sweden       Sweden       Canada       Canada
# 7       Sweden   Luxembourg  New Zealand  New Zealand  New Zealand
# 8  New Zealand  New Zealand      Austria       Sweden       Sweden
# 9    Australia      Austria   Luxembourg    Australia    Australia
#
#           2020         2021         2022
# 0       Norway      Denmark      Finland
# 1      Denmark  Switzerland      Denmark
# 2      Iceland      Iceland      Iceland
# 3  Switzerland       Norway  Switzerland
# ...

# %%
unhappiest= countries.tail(10)
unhappiest
# Out:
#                     2015          2016          2017         2018  \
# 137                 Mali  Sierra Leone         Egypt      Ukraine
# 138  Congo (Brazzaville)         India  Sierra Leone         Togo
# 139              Comoros       Burundi       Burundi       Guinea
# 140               Uganda         Yemen        Zambia      Lesotho
# 141              Senegal      Tanzania         Haiti       Angola
# 142                Gabon         Haiti       Lesotho   Madagascar
# 143                Niger        Malawi         India     Zimbabwe
# 144             Cambodia       Lesotho        Malawi  Afghanistan
# 145             Tanzania      Botswana         Yemen     Botswana
# 146           Madagascar        Rwanda      Botswana       Malawi
#
#             2019         2020          2021          2022
# 137      Ukraine     Zimbabwe       Comoros        Malawi
# 138         Togo      Lesotho   Ivory Coast      Tanzania
# 139       Guinea       Angola      Cambodia  Sierra Leone
# ...

# %%
happiest
# Out:
#           2015         2016         2017         2018         2019  \
# 0  Switzerland      Finland      Finland      Finland      Finland
# 1      Iceland      Denmark      Denmark       Norway       Norway
# 2      Denmark  Switzerland  Switzerland      Denmark      Denmark
# 3       Norway      Iceland      Iceland      Iceland      Iceland
# 4       Canada  Netherlands       Norway  Switzerland  Switzerland
# 5      Finland       Norway  Netherlands  Netherlands  Netherlands
# 6  Netherlands       Sweden       Sweden       Canada       Canada
# 7       Sweden   Luxembourg  New Zealand  New Zealand  New Zealand
# 8  New Zealand  New Zealand      Austria       Sweden       Sweden
# 9    Australia      Austria   Luxembourg    Australia    Australia
#
#           2020         2021         2022  Rank
# 0       Norway      Denmark      Finland     1
# 1      Denmark  Switzerland      Denmark     2
# 2      Iceland      Iceland      Iceland     3
# ...

# %%
unhappiest.insert(0, 'Rank', range(1, 11))
unhappiest
# Out:
#      Rank                 2015          2016          2017         2018  \
# 137     1                 Mali  Sierra Leone         Egypt      Ukraine
# 138     2  Congo (Brazzaville)         India  Sierra Leone         Togo
# 139     3              Comoros       Burundi       Burundi       Guinea
# 140     4               Uganda         Yemen        Zambia      Lesotho
# 141     5              Senegal      Tanzania         Haiti       Angola
# 142     6                Gabon         Haiti       Lesotho   Madagascar
# 143     7                Niger        Malawi         India     Zimbabwe
# 144     8             Cambodia       Lesotho        Malawi  Afghanistan
# 145     9             Tanzania      Botswana         Yemen     Botswana
# 146    10           Madagascar        Rwanda      Botswana       Malawi
#
#             2019         2020          2021          2022
# 137      Ukraine     Zimbabwe       Comoros        Malawi
# 138         Togo      Lesotho   Ivory Coast      Tanzania
# ...

# %%
happiest.to_csv('happiest.csv', index=False)

# %%
unhappiest.to_csv('unhappiest.csv', index=False)

# %%
df2.tail(10)
# Out:
#          Country                           Region  Happiness Rank  \
# 147   Madagascar               Sub-Saharan Africa             148
# 148     Tanzania               Sub-Saharan Africa             149
# 149      Liberia               Sub-Saharan Africa             150
# 150       Guinea               Sub-Saharan Africa             151
# 151       Rwanda               Sub-Saharan Africa             152
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 147            3.695                      3.621                      3.769
# 148            3.666                      3.561                      3.771
# ...
